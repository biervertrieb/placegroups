# %%
from src.visualization.visuialization_functions import plot_pixellist,new_xyt_plot
import matplotlib.pyplot as plt

xs = [100,500,1000,1500]
ys = [1500,1200,1000,800]
ts = [300,360,420,480]

subplot = new_xyt_plot()



subplot = plot_pixellist([xs,ys,ts],color='red',subplot=subplot,finish=False)

plt.show()
